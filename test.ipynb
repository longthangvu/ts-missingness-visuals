# %%
from utils.get_data import *

# %%
data_singleton = get_data()

# %%
data_singleton.get_data('India')
# Out:
#          NH3   NO2    CO  PM2.5   Temp  Pressure  Humidity     O3  \
# 0       0.60  0.16  4.01   0.00  33.53    948.26     51.98   7.37
# 1       0.62  0.15  4.13   0.39  33.50    948.18     51.53   9.06
# 2       0.69  0.14  4.45   0.39  33.36    948.15     50.50  16.47
# 3       0.70  0.14  4.52   0.38  32.18    948.14     53.35   9.80
# 4       0.72  0.14  4.56   0.40  31.77    948.08     53.70  17.28
# ...      ...   ...   ...    ...    ...       ...       ...    ...
# 173460  0.49  0.18  3.28   0.00  26.19    930.53     83.68   5.10
# 173461  0.48  0.18  3.28   0.00  26.15    930.53     83.53   5.18
# 173462  0.47  0.18  3.28   0.00  26.15    930.53     83.76   5.18
# 173463  0.48  0.18  3.28   0.00  26.16    930.49     83.78   5.18
# 173464  0.48  0.18  3.28   0.00  26.19    930.50     83.71   5.18
#
#                              Date
# 0      2020-11-17 11:20:53.407872
# 1      2020-11-17 11:22:41.214724
# 2      2020-11-17 11:24:28.546567
# 3      2020-11-17 11:26:16.884289
# 4      2020-11-17 11:28:19.820781
# ...                           ...
# 173460 2022-07-14 06:36:51.411260
# 173461 2022-07-14 06:37:48.752963
# 173462 2022-07-14 06:38:45.008995
# 173463 2022-07-14 06:39:42.306449
# 173464 2022-07-14 06:40:39.653879
#
# [173465 rows x 9 columns]

# %%
import importlib
import utils.helper_functions
importlib.reload(utils.helper_functions)
from utils.helper_functions import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 3
#       1 import importlib
#       2 import utils.helper_functions
# ----> 3 importlib.reload(utils.helper_functions)
#       4 from utils.helper_functions import *
#
# File /usr/lib/python3.10/importlib/__init__.py:169, in reload(module)
#     167 if spec is None:
#     168     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 169 _bootstrap._exec(spec, module)
#     170 # The module may have replaced itself in sys.modules!
#     171 return sys.modules[name]
#
# File <frozen importlib._bootstrap>:619, in _exec(spec, module)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/playground/ts-missingness-visuals/utils/helper_functions.py:67
#      64     expected = int(interval_length / median_delta)
#      65     return expected
# ---> 67 from utils.co_coverage import compute_partial_co_coverage_vector
#      68 import pandas as pd
#      70 def gather_cross_dataset_co_coverage(data_singleton, dataset_names, start_date, end_date, feature_pool):
#
# ImportError: cannot import name 'compute_partial_co_coverage_vector' from 'utils.co_coverage' (/home/lvu/playground/ts-missingness-visuals/utils/co_coverage.py)

# %%
india_df = data_singleton.get_data('India')
df_daily = resample_time_series(india_df, freq='D')
df_daily
# Out:
#           Date       NH3       NO2        CO     PM2.5       Temp    Pressure  \
# 0   2020-11-17  0.911429  0.129286  5.322143  0.366429  31.672143  947.968571
# 1   2020-11-18       NaN       NaN       NaN       NaN        NaN         NaN
# 2   2020-11-19       NaN       NaN       NaN       NaN        NaN         NaN
# 3   2020-11-20       NaN       NaN       NaN       NaN        NaN         NaN
# 4   2020-11-21  0.894242  0.124242  5.304545  0.000000  31.090303  947.773333
# ..         ...       ...       ...       ...       ...        ...         ...
# 600 2022-07-10  0.432716  0.188553  3.148771  0.000000  27.161223  934.785274
# 601 2022-07-11  0.463380  0.183082  3.254246  0.000000  26.837050  936.181938
# 602 2022-07-12  0.480939  0.179630  3.324504  0.000000  26.609497  935.793677
# 603 2022-07-13  0.464742  0.182295  3.238644  0.000000  26.448075  933.061071
# 604 2022-07-14  0.476152  0.180000  3.276770  0.000000  26.280760  930.651473
#
#       Humidity         O3
# 0    54.468571  16.218571
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4    59.650303  17.656970
# ..         ...        ...
# 600  82.285403   5.264296
# 601  84.975304   5.562414
# 602  85.558173   5.761104
# 603  85.739728   5.237533
# 604  84.228310   5.177387
#
# [605 rows x 9 columns]

# %%
from utils.plot_functions import plot_time_series_heatmap

plot_time_series_heatmap(df_daily).show()

# %%
from utils.missingness import *

# %%
res_df = reconstruct_time_index(df_daily)
gaps = compute_gap_stats(res_df)
gaps
# Out:
#     feature  num_gaps   mean_gap  max_gap
# 0       NH3        17  23.000000      136
# 1       NO2        17  23.000000      136
# 2        CO        17  23.000000      136
# 3     PM2.5        17  23.000000      136
# 4      Temp        18  22.055556      136
# 5  Pressure        18  22.055556      136
# 6  Humidity        18  22.055556      136
# 7        O3        17  23.000000      136

# %%
importlib.reload(utils.plot_functions)
from utils.plot_functions import *

# %%
plot_temporal_coverage_heatmap(data_singleton.get_data('India')).show()

# %%
plot_temporal_coverage_heatmap(data_singleton.get_data('Sweden Bedroom')).show()

# %%
pollutants = ['PM_MET_IN1','CO2_ETC_IN1','NO2_AQL_IN1','T_ETC_IN1','RH_ETC_IN1','FRM_ADJ_IN1']
start_date = '2016-07-12'
end_date = '2018-04-09'

target_datasets = [name for name in data_singleton._data_store if name.startswith("Caliapt")]

vectors, names = gather_cross_dataset_co_coverage(
    data_singleton,
    dataset_names=target_datasets,
    start_date=start_date,
    end_date=end_date,
    feature_pool=pollutants
)

fig = plot_parallel_coordinates(vectors, pollutants, names)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       3 end_date = '2018-04-09'
#       5 target_datasets = [name for name in data_singleton._data_store if name.startswith("Caliapt")]
# ----> 7 vectors, names = gather_cross_dataset_co_coverage(
#       8     data_singleton,
#       9     dataset_names=target_datasets,
#      10     start_date=start_date,
#      11     end_date=end_date,
#      12     feature_pool=pollutants
#      13 )
#      15 fig = plot_parallel_coordinates(vectors, pollutants, names)
#      16 fig.show()
#
# TypeError: gather_cross_dataset_co_coverage() got an unexpected keyword argument 'feature_pool'
